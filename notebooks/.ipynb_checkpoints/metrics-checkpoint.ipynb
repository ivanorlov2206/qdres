# %%
import pickle

from keras.models import load_model
import numpy as np
from keras.utils import np_utils
import json
from sklearn import metrics
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import quickdraw
import sys

model_files = ["baseline", "from_github", "vggnet"]
classes = ['book', 'sun', 'banana', 'apple', 'bowtie', 'ice cream', 'eye', 'square', 'cup', 'door', 'sword', 'star', 'fish', 'donut', 'mountain']

# %%
def loadFromPickle():
    with open("../features", "rb") as f:
        features = np.array(pickle.load(f))
    with open("../labels", "rb") as f:
        labels = np.array(pickle.load(f))

    return features, labels


def augmentData(features, labels):
    features = np.append(features, features[:, :, ::-1], axis=0)
    labels = np.append(labels, -labels, axis=0)
    return features, labels


def prepress_labels(labels):
    labels = np_utils.to_categorical(labels)
    return labels


def get_eval(y_true, y_prob):
    output = {}
    print(y_prob.shape, y_true.shape)
    output['accuracy'] = metrics.accuracy_score(y_true, y_prob)
    output['classification_report'] = metrics.classification_report(y_true, y_prob, target_names=classes)
    output['confusion_matrix'] = np.reshape(metrics.confusion_matrix(y_true, y_prob), (15, 15)).tolist()
    return output

# %%
features, labels = loadFromPickle()
features, labels = shuffle(features, labels)
labels=prepress_labels(labels)
train_x, test_x, train_y, test_y = train_test_split(features, labels, random_state=1,
                                                    test_size=0.2)
train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.25, random_state=1)
train_x = train_x.reshape(train_x.shape[0], 28, 28, 1)
test_x = test_x.reshape(test_x.shape[0], 28, 28, 1)
valid_x = valid_x.reshape(test_x.shape[0], 28, 28, 1)

# %%
model = load_model("../" + model_files[0] + ".h5") # Baseline
# Out:
# WARNING:tensorflow:From /home/mineorpe/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/mineorpe/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/mineorpe/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/mineorpe/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/mineorpe/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/mineorpe/.local/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/mineorpe/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
y_prob = model.predict_classes(test_x)
print(y_prob, np.argmax(test_y, axis=-1))
eval = get_eval(np.argmax(test_y, axis=-1), y_prob)
# Out:
# [ 6 11 11 ...  7 10  9] [ 6  4 11 ...  7 10  9]
# (30000,) (30000,)

# %%
from IPython.display import Image
Image("../models_info/baseline_struct.png")

# %%
import matplotlib.pyplot

matplotlib.pyplot.matshow(eval["confusion_matrix"])
eval["accuracy"]
print(eval["classification_report"])
# Out:
#               precision    recall  f1-score   support
#
#         book       0.94      0.94      0.94      1973
#          sun       0.97      0.95      0.96      2016
#       banana       0.96      0.95      0.96      1964
#        apple       0.97      0.97      0.97      2089
#       bowtie       0.96      0.93      0.94      2021
#    ice cream       0.98      0.97      0.98      2024
#          eye       0.93      0.93      0.93      1955
#       square       0.97      0.95      0.96      1991
#          cup       0.92      0.93      0.93      1966
#         door       0.94      0.94      0.94      1955
#        sword       0.93      0.96      0.95      1979
#         star       0.94      0.95      0.94      2023
#         fish       0.91      0.95      0.93      2028
#        donut       0.97      0.96      0.96      2015
#     mountain       0.96      0.96      0.96      2001
#
#     accuracy                           0.95     30000
#    macro avg       0.95      0.95      0.95     30000
# weighted avg       0.95      0.95      0.95     30000

# %%
from keras import backend as K

# %%
K.clear_session()

# %%
model = load_model("../" + model_files[1] + ".h5") # From github
# Out:
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
y_prob = model.predict_classes(test_x)

print(y_prob, np.argmax(test_y, axis=-1))

eval = get_eval(np.argmax(test_y, axis=-1), y_prob)
# Out:
# [ 8  4 11 ...  7 10  9] [ 6  4 11 ...  7 10  9]
# (30000,) (30000,)

# %%
Image("../models_info/from_github_struct.png")

# %%
matplotlib.pyplot.matshow(eval["confusion_matrix"])
eval["accuracy"]
print(eval["classification_report"])
# Out:
#               precision    recall  f1-score   support
#
#         book       0.96      0.94      0.95      1973
#          sun       0.98      0.97      0.98      2016
#       banana       0.98      0.98      0.98      1964
#        apple       0.99      0.98      0.98      2089
#       bowtie       0.96      0.95      0.95      2021
#    ice cream       0.98      0.98      0.98      2024
#          eye       0.94      0.97      0.95      1955
#       square       0.94      0.96      0.95      1991
#          cup       0.95      0.96      0.95      1966
#         door       0.98      0.93      0.95      1955
#        sword       0.96      0.97      0.97      1979
#         star       0.96      0.97      0.97      2023
#         fish       0.97      0.96      0.97      2028
#        donut       0.97      0.97      0.97      2015
#     mountain       0.96      0.98      0.97      2001
#
#     accuracy                           0.96     30000
#    macro avg       0.96      0.96      0.96     30000
# weighted avg       0.97      0.96      0.96     30000

# %%
K.clear_session()
model = load_model("../" + model_files[2] + ".h5") # VGG Net
y_prob = model.predict_classes(test_x)

print(y_prob, np.argmax(test_y, axis=-1))

eval = get_eval(np.argmax(test_y, axis=-1), y_prob)
# Out:
# [13  4 11 ...  7 10  9] [ 6  4 11 ...  7 10  9]
# (30000,) (30000,)

# %%
Image("../models_info/vggnet_struct.png")

# %%
matplotlib.pyplot.matshow(eval["confusion_matrix"])
eval["accuracy"]
print(eval["classification_report"])
# Out:
#               precision    recall  f1-score   support
#
#         book       0.92      0.95      0.93      1973
#          sun       0.97      0.98      0.97      2016
#       banana       0.96      0.97      0.97      1964
#        apple       0.98      0.98      0.98      2089
#       bowtie       0.94      0.93      0.93      2021
#    ice cream       0.97      0.98      0.98      2024
#          eye       0.92      0.93      0.93      1955
#       square       0.93      0.95      0.94      1991
#          cup       0.95      0.92      0.93      1966
#         door       0.94      0.94      0.94      1955
#        sword       0.97      0.95      0.96      1979
#         star       0.97      0.96      0.96      2023
#         fish       0.96      0.94      0.95      2028
#        donut       0.95      0.97      0.96      2015
#     mountain       0.97      0.97      0.97      2001
#
#     accuracy                           0.95     30000
#    macro avg       0.95      0.95      0.95     30000
# weighted avg       0.95      0.95      0.95     30000
